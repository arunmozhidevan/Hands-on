# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
X = 2 * np.random.rand(n, 1)
y = 4 + 3 * X + np.random.randn(n, 1)

# %%
plt.plot(X, y, "b.")

# %% [markdown]
# ### LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X,y)
X_new = np.linspace(0, 2, n).reshape(n,1)
y_p = lr.predict(X_new)

# %%
plt.plot(X,y,"b.", label="Data points")
plt.plot(X_new,y_p,"r-", linewidth=2, label="Predictions")
plt.axis([0,2,2,12])
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("y", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)

# %% [markdown]
# ### RidgeRegression

# %%
from sklearn.linear_model import Ridge

# %%
rr = Ridge(alpha=1, solver='cholesky')

# %%
rr.fit(X,y)
# Out:
# Ridge(alpha=1, solver='cholesky')

# %%
rr.predict([[1.5]])
# Out:
# array([[8.7626267]])

# %%
X_r = np.linspace(0, 2, n).reshape(n,1)
y_r = rr.predict(X_new)

# %%
plt.plot(X,y,"b.")
plt.plot(X_new,y_p,"r-", linewidth=2, label="Least Square")
plt.plot(X_r,y_r,"g-", linewidth=2, label="Ridge")
plt.axis([0,2,2,12])
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("y", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
la_r = Lasso(alpha=0.1)

# %%
la_r.fit(X,y)
# Out:
# Lasso(alpha=0.1)

# %%
X_la = np.linspace(0, 2, n).reshape(n,1)
y_la = la_r.predict(X_new)

# %%
plt.plot(X,y,"b.")
plt.plot(X_new,y_p,"r--", linewidth=2, label="Least Square")
plt.plot(X_r,y_r,"g-", linewidth=2, label="Ridge")
plt.plot(X_la,y_la,"c-", linewidth=1, label="Lasso")
plt.axis([0,2,2,12])
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("y", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)

# %% [markdown]
# ### Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet

# %%
ENr = ElasticNet(alpha=0.1, l1_ratio=0.5)

# %%
ENr.fit(X,y)
# Out:
# ElasticNet(alpha=0.1)

# %%
X_ENr = np.linspace(0, 2, n).reshape(n,1)
y_ENr = ENr.predict(X_new)

# %%
plt.plot(X,y,"b.")
plt.plot(X_new,y_p,"r--", linewidth=2, label="Least Square")
plt.plot(X_r,y_r,"g-", linewidth=2, label="Ridge")
plt.plot(X_la,y_la,"c-", linewidth=1, label="Lasso")
plt.plot(X_ENr,y_ENr,"m-", linewidth=1, label="Elastic Net")
plt.axis([0,2,2,12])
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("y", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)

# %%
value = [[1.5]]
lr.predict(value), rr.predict(value), la_r.predict(value), ENr.predict(value)
# Out:
# (array([[8.80063132]]),
#  array([[8.7626267]]),
#  array([8.67053317]),
#  array([8.57200409]))
